# %% [markdown]
# # Oefening 7.1 - Een histogram van doorlooptijden maken
#
# **Niveau:** Basis
# **Geschatte tijd:** 25 tot 35 minuten
# **Benodigde packages:** numpy, matplotlib
#
# ## Doel
#
# De verdeling, scheefheid en uitschieters in numerieke data herkennen.
#
# ## Opdracht
#
# Genereer voorbeelddata met normale doorlooptijden en enkele zeer hoge waarden. Maak een histogram en teken lijnen voor gemiddelde en mediaan.
#
#
#
# Werk stap voor stap:
#
#
# 1. Maak de voorbeelddata en bereken eerst de belangrijkste statistieken.
#
# 2. Kies een grafiek die past bij de vraag.
#
# 3. Voeg een duidelijke titel, asnamen en eenheden toe.
#
# 4. Vergelijk de grafiek met de berekende waarden.
#
# 5. Schrijf op wat de grafiek wel laat zien en wat niet kan worden geconcludeerd.
#
# Hint: Een grafiek is pas duidelijk wanneer de lezer zonder de code begrijpt wat op beide assen staat.
#
# ## Werkwijze
#
# 1. Probeer de opdracht eerst zelf.
# 2. Voer de code uit en controleer de tussenresultaten.
# 3. Voeg minimaal één randgeval toe.
# 4. Open pas daarna `uitwerking.py` en `uitwerking.md`.

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.default_rng(42)
doorlooptijden = np.concatenate([
    rng.normal(loc=8, scale=2, size=180),
    np.array([20, 28, 35]),
])
doorlooptijden = np.clip(doorlooptijden, 0, None)

gemiddelde = doorlooptijden.mean()
mediaan = np.median(doorlooptijden)

plt.hist(doorlooptijden, bins=20, edgecolor="black")
plt.axvline(gemiddelde, linestyle="--", label=f"Gemiddelde: {gemiddelde:.1f}")
plt.axvline(mediaan, linestyle=":", label=f"Mediaan: {mediaan:.1f}")
plt.xlabel("Doorlooptijd in dagen")
plt.ylabel("Aantal")
plt.title("Verdeling van doorlooptijden")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Uitwerking 7.1
#
# ## Hoe werkt de code?
#
# De drie hoge waarden trekken het gemiddelde naar rechts. De mediaan reageert minder sterk op uitschieters. Het histogram maakt zichtbaar waarom een enkel gemiddelde onvoldoende kan zijn voor operationele rapportage.
#
#
# ## Verwachte uitvoer
#
# De grafiek is rechts-scheef. Het gemiddelde ligt iets rechts van de mediaan.
#
#
# ## Controleer je uitkomst
#
# - Assen hebben eenheid en betekenis.
# - De keuze van bins verbergt het patroon niet.
# - Gemiddelde en mediaan worden beide getoond.
#
# ## Verdiepingsopdracht
#
# Maak dezelfde grafiek zonder de drie uitschieters en vergelijk de statistieken.
#
#
# ## Zelf verder testen
#
# Verander minimaal één invoerwaarde en voeg een randgeval toe. Controleer daarna of de conclusie nog steeds door de uitvoer wordt ondersteund.
